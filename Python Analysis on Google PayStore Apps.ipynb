# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\HP\Downloads\playstore\googleplaystore.csv")

# %%
#Show the TOP 20 rows of the dataset


data.head(20)
# Out:
#                                                   App        Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                 Coloring book moana  ART_AND_DESIGN     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                               Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                          Paper flowers instructions  ART_AND_DESIGN     4.4
# 6             Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                    Infinite Painter  ART_AND_DESIGN     4.1
# 8                                Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                       Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
# 10                            Text on Photo - Fonteee  ART_AND_DESIGN     4.4
# ...

# %%
#Show the BOTTOM 20 rows of the dataset


data.tail(5)
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
#Showing the number of rows and number of columns in the dataset

data.shape
# Out:
# (10841, 13)

# %%
print("The Number of Rows is",data.shape[0])
print("The Number of Columns is",data.shape[1])
# Out:
# The Number of Rows is 10841
# The Number of Columns is 13

# %%
#More info about the data


data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
#Statistics about the the dataset(only numerical values)

data.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
#Statistics about the the dataset(including non-numerical values)

data.describe(include = "all")
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
# Total number of apps titles that contain Python & R

data['App']
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10836                                     Sya9a Maroc - FR
# 10837                     Fr. Mike Schmitz Audio Teachings
# 10838                               Parkinson Exercices FR
# 10839                        The SCP Foundation DB fr nn5n
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10841, dtype: object

# %%
data['App'].str.contains('Python')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840    False
# Name: App, Length: 10841, dtype: bool

# %%
data[data['App'].str.contains('Python', case=False)]
# Out:
#                                    App   Category  Rating Reviews  Size  \
# 752                  Quiz&Learn Python  EDUCATION     4.0     304  2.0M
# 4528  DataCamp - Learn R, Python & SQL     FAMILY     4.4     944   12M
# 5207           AI with Python Tutorial     FAMILY     4.4       8  3.3M
#
#       Installs  Type Price Content Rating     Genres    Last Updated  \
# 752    10,000+  Free     0       Everyone  Education    July 4, 2016
# 4528  100,000+  Free     0       Everyone  Education  August 1, 2018
# 5207    5,000+  Free     0       Everyone  Education    June 5, 2018
#
#      Current Ver Android Ver
# 752        1.3.0  4.0 and up
# 4528       3.1.0  4.1 and up
# 5207       1.0.4  4.1 and up

# %%
data['App'].str.contains('Python','R')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840    False
# Name: App, Length: 10841, dtype: bool

# %%
data[data['App'].str.contains('Python','R')]
# Out:
#                                    App   Category  Rating Reviews  Size  \
# 752                  Quiz&Learn Python  EDUCATION     4.0     304  2.0M
# 4528  DataCamp - Learn R, Python & SQL     FAMILY     4.4     944   12M
# 5207           AI with Python Tutorial     FAMILY     4.4       8  3.3M
#
#       Installs  Type Price Content Rating     Genres    Last Updated  \
# 752    10,000+  Free     0       Everyone  Education    July 4, 2016
# 4528  100,000+  Free     0       Everyone  Education  August 1, 2018
# 5207    5,000+  Free     0       Everyone  Education    June 5, 2018
#
#      Current Ver Android Ver
# 752        1.3.0  4.0 and up
# 4528       3.1.0  4.1 and up
# 5207       1.0.4  4.1 and up

# %%
# Total number of apps titles that contain Programming

data[data['App'].str.contains('Programing')]
# Out:
#                                 App             Category  Rating Reviews  \
# 4539  R Programing Offline Tutorial  BOOKS_AND_REFERENCE     5.0       4
#
#       Size Installs  Type Price Content Rating             Genres  \
# 4539  3.9M   1,000+  Free     0       Everyone  Books & Reference
#
#         Last Updated Current Ver Android Ver
# 4539  March 15, 2018       1.0.0  4.1 and up

# %%
#Find the average app rating

data['Rating'].mean()
# Out:
# 4.193338315362448

# %%
#Find the total number of unique catagory

data['Category'].nunique()
# Out:
# 34

# %%
#Category with the highest average rating

data.groupby('Category')['Rating'].mean().sort_values(ascending=False)
# Out:
# Category
# 1.9                    19.000000
# EVENTS                  4.435556
# EDUCATION               4.389032
# ART_AND_DESIGN          4.358065
# BOOKS_AND_REFERENCE     4.346067
# PERSONALIZATION         4.335987
# PARENTING               4.300000
# GAME                    4.286326
# BEAUTY                  4.278571
# HEALTH_AND_FITNESS      4.277104
# SHOPPING                4.259664
# SOCIAL                  4.255598
# WEATHER                 4.244000
# SPORTS                  4.223511
# PRODUCTIVITY            4.211396
# HOUSE_AND_HOME          4.197368
# FAMILY                  4.192272
# PHOTOGRAPHY             4.192114
# AUTO_AND_VEHICLES       4.190411
# MEDICAL                 4.189143
# LIBRARIES_AND_DEMO      4.178462
# FOOD_AND_DRINK          4.166972
# COMMUNICATION           4.158537
# COMICS                  4.155172
# NEWS_AND_MAGAZINES      4.132189
# FINANCE                 4.131889
# ENTERTAINMENT           4.126174
# BUSINESS                4.121452
# ...

# %%
#Total number of apps with 5 star rating

len(data[data['Rating']==5.0])
# Out:
# 274

# %%
#The average values of reviews

data['Reviews'].dtype
# Out:
# dtype('O')

# %%
#Converting it from 'object' to either int or float

#data['Reviews'].astype('float')

data[data['Reviews']=='3.0M']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
data['Reviews']=data['Reviews'].replace('3.0M',3.0)

# %%
data['Reviews']=data['Reviews'].astype('float')

# %%
data['Reviews'].dtype
# Out:
# dtype('float64')

# %%
#Finally the average values of reviews

data['Reviews'].mean()
# Out:
# 444111.9265750392

# %%
#Total number of Free and Paid Apps

data['Type'].value_counts()
# Out:
# Free    10039
# Paid      800
# 0           1
# Name: Type, dtype: int64

# %%
#App with the maximum reviews

data[data['Reviews'].max()==data['Reviews']]
# Out:
#            App Category  Rating     Reviews                Size  \
# 2544  Facebook   SOCIAL     4.1  78158306.0  Varies with device
#
#             Installs  Type Price Content Rating  Genres    Last Updated  \
# 2544  1,000,000,000+  Free     0           Teen  Social  August 3, 2018
#
#              Current Ver         Android Ver
# 2544  Varies with device  Varies with device

# %%
#Name of the app with the maximum reviews

data[data['Reviews'].max()==data['Reviews']]['App']
# Out:
# 2544    Facebook
# Name: App, dtype: object

# %%
#Top 10 apps having highest reviews

index=data['Reviews'].sort_values(ascending=False).head(10).index

# %%
data.iloc[index]['App']
# Out:
# 2544                                    Facebook
# 3943                                    Facebook
# 381                           WhatsApp Messenger
# 336                           WhatsApp Messenger
# 3904                          WhatsApp Messenger
# 2604                                   Instagram
# 2611                                   Instagram
# 2545                                   Instagram
# 3909                                   Instagram
# 382     Messenger – Text and Video Chat for Free
# Name: App, dtype: object

# %%
#Average rating of free and paid apps

data.groupby('Type')['Rating'].mean()
# Out:
# Type
# 0       19.000000
# Free     4.186203
# Paid     4.266615
# Name: Rating, dtype: float64

# %%
#Top 10 app having maximum installs

data['Installs'].dtype
# Out:
# dtype('O')

# %%
#View the content of 'Installs'

data['Installs']
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10836         5,000+
# 10837           100+
# 10838         1,000+
# 10839         1,000+
# 10840    10,000,000+
# Name: Installs, Length: 10841, dtype: object

# %%
#Removing to the ',' and '+' to enavle us convert to int

data['New_Installs']=data['Installs'].str.replace(',','')

# %%
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size     Installs  Type Price Content Rating  \
# 0     159.0   19M      10,000+  Free     0       Everyone
# 1     967.0   14M     500,000+  Free     0       Everyone
# 2   87510.0  8.7M   5,000,000+  Free     0       Everyone
# 3  215644.0   25M  50,000,000+  Free     0           Teen
# 4     967.0  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
data['New_Installs']=data['New_Installs'].str.replace('+','')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19184\2059960068.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['New_Installs']=data['New_Installs'].str.replace('+','')

# %%
#Removing to the ',' and '+' to enavle us convert to int

data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size     Installs  Type Price Content Rating  \
# 0     159.0   19M      10,000+  Free     0       Everyone
# 1     967.0   14M     500,000+  Free     0       Everyone
# 2   87510.0  8.7M   5,000,000+  Free     0       Everyone
# 3  215644.0   25M  50,000,000+  Free     0           Teen
# 4     967.0  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
#Converting 'Free' to '0'

data[data['New_Installs']=='Free']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver, New_Installs]
# Index: []

# %%
data['New_Installs']=data['New_Installs'].str.replace('Free','0')

# %%
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size     Installs  Type Price Content Rating  \
# 0     159.0   19M      10,000+  Free     0       Everyone
# 1     967.0   14M     500,000+  Free     0       Everyone
# 2   87510.0  8.7M   5,000,000+  Free     0       Everyone
# 3  215644.0   25M  50,000,000+  Free     0           Teen
# 4     967.0  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
#Finally converting to int

data['New_Installs']=data['New_Installs'].astype('int')

# %%
data['New_Installs'].dtype
# Out:
# dtype('int32')

# %%
#TOP10 app having maximum installs

index=data['New_Installs'].sort_values(ascending=False).head(10).index

# %%
data.iloc[index]
# Out:
#                                            App       Category  Rating  \
# 3896                            Subway Surfers           GAME     4.5
# 3943                                  Facebook         SOCIAL     4.1
# 335   Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 3523                              Google Drive   PRODUCTIVITY     4.4
# 3565                              Google Drive   PRODUCTIVITY     4.4
# 2884                             Google Photos    PHOTOGRAPHY     4.5
# 3665                                   YouTube  VIDEO_PLAYERS     4.3
# 2853                             Google Photos    PHOTOGRAPHY     4.5
# 4234             Skype - free IM & video calls  COMMUNICATION     4.1
# 3687                   Google Play Movies & TV  VIDEO_PLAYERS     3.7
#
#          Reviews                Size        Installs  Type Price  \
# 3896  27711703.0                 76M  1,000,000,000+  Free     0
# ...

# %%
#Name of TOP10 app having maximum installs

data.iloc[index]['App']
# Out:
# 3896                              Subway Surfers
# 3943                                    Facebook
# 335     Messenger – Text and Video Chat for Free
# 3523                                Google Drive
# 3565                                Google Drive
# 2884                               Google Photos
# 3665                                     YouTube
# 2853                               Google Photos
# 4234               Skype - free IM & video calls
# 3687                     Google Play Movies & TV
# Name: App, dtype: object
